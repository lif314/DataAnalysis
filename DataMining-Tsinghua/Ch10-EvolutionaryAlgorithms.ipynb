# %% [markdown]
# # <center> Ch10 Evolutionary Algorithms </center>

# %% [markdown]
# ## Overview

# %% [markdown]
# - Global Optimization
# - Genetic Algorithms
# - Genetic Programming
# - Evolvable Things（可进化的硬件）
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 遗传论(孟德尔)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Motivation of EAs

# %% [markdown]
# - 优化
# - 理解自然界
# ![image.png](attachment:image.png)

# %% [markdown]
# ###  Key Concepts

# %% [markdown]
# **进化计算概念**
# - Population-Based Stochastic(随机搜索) Optimization Methods：多点优化。BP是单点的，从一个点开始梯度下降进行计算
# - 并行：不容易陷入局部最优点
# - 染色体、杂交、变异
# - 适者生存
# - (Meta)启发式搜索:方法不局限于个别问题
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **宏观图谱**
# ![image.png](attachment:image.png)

# %% [markdown]
# ### EA Family

# %% [markdown]
# - GA: Genetic Algorithm
# - GP: Genetic Programming
# - ES: Evolution Strategies
# - EP: Evolutionary Programming
#
#
# - EDA: Estimation of Distribution Algorithm
# - PSO: Particle Swarm Optimization
# - ACO: Ant Colony Optimization
# - DE: Differential Evolution

# %% [markdown]
# - 蚂蚁留下信息素：慢慢收敛到最短的路径
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Objective Function

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 经典问题

# %% [markdown]
# - **Portfolio Optimization 投资优化**
# - **Travelling Salesman Problem 旅行商问题**
# - **Knapsack Problem 背包问题**
# - **Bin Packing Problem 装箱问题**
# - **Machine Learning Problems**
#     - Regression
#     - Classification

# %% [markdown]
# **计算机计算速度**
# ![image.png](attachment:image.png)

# %% [markdown]
# 地球做计算机$10^{75}$

# %% [markdown]
# ## 解决方法

# %% [markdown]
# - Local Search
# ![image.png](attachment:image.png)

# %% [markdown]
# - Divide and Conquer: 等高线，找最优点
#     - n维问题不能简单拆成多个1维问题
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Parallel Search**
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Blondie24: 跳棋，自学习，没有人交。协同进化。自己与自己学习

# %% [markdown]
# ## Genetic Algorithms
