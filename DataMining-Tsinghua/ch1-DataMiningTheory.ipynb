# %% [markdown]
# # <center> chapter1  Data Mining Theory </center>

# %% [markdown]
# ## Introdcution

# %% [markdown]
# - The Word of Data
# - Data Rich, Informatiion Poor

# %% [markdown]
# - Learning Resourses
# ![image.png](attachment:image.png)

# %% [markdown]
# - Google
# - UCI dataset
# - Weka  -- DataMinig software
# - KD nuggets

# %% [markdown]
# 多学科交叉
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The value of a college education is not the learning of many facts but the training of the mind to think.
#
# --- Albert Einstein

# %% [markdown]
# ## Data

# %% [markdown]
# - Data Types
#     - Continuous, Binary
#     - Discrete, String
#     - Symbolic
# - Storage
#     -  Physical
#     - Logical
# - Major issues
#     - Transformation
#     - Errors and Corruption
# - Big Data
#     - high-volume, high-velocity, high-variety
# - Application
#     - Urban planning
#     - Health
#     - Mobile Location
#     - Shopper: favorites, walking map
#     - Targeted Marketing
#     - Sentiment Analysis（情感分析）
#     - Social Networks
#     - Sports: 棒球 点球成金
#     - Attractiveness Mining （什么样的人具有吸引力？ -- 衡量标准）

# %% [markdown]
# ## Open Data

# %% [markdown]
# - Technically Open
# - Legally Open

# %% [markdown]
# ## Data Mining

# %% [markdown]
# - useful hidden, massive, interesting
# - Not a fully automatic process
# - From Data to Intelligence
# ![image.png](attachment:image.png)
#
# - Data Integration & Analysis
# - Data Mining Process: waterfall Model
# - Tools: SAP

# %% [markdown]
# ## DM Techniques -- Classification

# %% [markdown]
# - Algorithms
#     - Decision Trees
#     - K-Nearest Neighbours
#     - Neural Networks
#     - Support Vector Machines
# - Problems
#     - Overfitting
#     ![image-2.png](attachment:image-2.png)
#     - Cross Validation
#     ![image.png](attachment:image.png)
#     - Confusion Matrix（混淆矩阵）
#        真假 & 预测的真假 --> 准确率
#     ![image-3.png](attachment:image-3.png)
#     - ROC(Receiver Operating Characteristic)
#     中间线 -- 阈值   召回率
#     ![image-5.png](attachment:image-5.png)
#     AUC(Area Under Curve)：曲线下面的面积，越大越好
#     - Cost Sensitive Learning (错误的代价成本问题)
#     正确邮件放在垃圾箱 & 垃圾邮件没有识别
#     - Lift Analysis：用模型与不用模型的差异度
#      评价模型在实际使用中的效果[营销应用]

# %% [markdown]
# ## DM Techniques - Clustering

# %% [markdown]
# - Clustering: No labels, 无监督学习  --> Groups
# - Distance Metrics（指标）
#     - Euclidean Distance
#     - Manhattan Distance （曼哈顿距离）
#     - Mahalanobis Distance （马氏距离）
# - Algorithms
#     - K-means
#     - Sequential Leader
#     - Affnity Propagation

# %% [markdown]
# **Hierarchical Clustering**
# 层次性聚类
# ![image.png](attachment:image.png)

# %% [markdown]
# **Association Rule**
# 关联关系：买了什么东西的人会买其它什么
#
# **Regression**
# ![image.png](attachment:image.png)
# 都是线性回归：线性指变量和参数是线性的，而拟合的结果可以是直线，也可以是曲线

# %% [markdown]
# **Seeing is Knowing** -- 数据可视化

# %% [markdown]
# **最有挑战的部分是数据的预处理，而不是算法 -- GIGO**
# ![image.png](attachment:image.png)
#
# - 预处理工作
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Other Problems
# - Privacy Protection
# 你吸过大麻吗
#
# 保护受试者的回到哪个问题
# ![image.png](attachment:image.png)

# %% [markdown]
# - Cloud Computing
#     - Software as a Service
#     - Platform as a Service
#     - Infrastructure as a Service
# - Parallel Computing
#     - GPU
#     - Mobile Supercomputing
#     - Intel MIC

# %% [markdown]
# ## Cases

# %% [markdown]
# - 股票预测
# - Grouping
# ![image.png](attachment:image.png)
# - 看大象的表情
# ![image-2.png](attachment:image-2.png)
